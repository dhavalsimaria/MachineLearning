# %% [markdown]
# ## To check the path of current working Dir

# %%
import os
os.getcwd()
# Out:
# 'F:\\All_Prep\\NLP Training\\Session\\1 Introduction to Text Mining and NLP'

# %%
path = 'F:/All_Prep/NLP Training'
os.chdir(path)
os.getcwd()
# Out:
# 'F:\\All_Prep\\NLP Training'

# %%
os.getcwd()
# Out:
# 'F:\\All_Prep\\NLP Training\\Session\\1 Introduction to Text Mining and NLP'

# %%
path = 'F:\\All_Prep\\NLP Training\\Session\\1 Introduction to Text Mining and NLP'
os.chdir(path)

# %% [markdown]
# ## Let's create a text file and read it

# %%
text_file = open("textfile.txt",'r')
text_file.read()
# Out:
# 'This is a test file that I want to read.\nThis is the second line of the text file.'

# %%
text_file2 = open("demo_text_file.txt", "w+")
text_file2.write('New Demo in Python to read text file.\nThis is our first demo and second try.')
text_file2.close()

# %%
text_file3 = open("demo_text_file.txt", "r")
text_file3.read()
# Out:
# 'New Demo in Python to read text file.\nThis is our first demo and second try.'

# %% [markdown]
# ## Let's work with a word docx ##

# %%
#!pip install python-docx
import docx
doc = docx.Document('Demo_Word.docx')

# %%
len(doc.paragraphs)
# Out:
# 4

# %%
doc.paragraphs[3].text
# Out:
# 'Sent 3'

# %%
len(doc.paragraphs[0].runs)
# Out:
# 2

# %%
doc.paragraphs[0].runs[1].text
# Out:
# '11.4 only request with secure links work. '

# %%
doc.add_paragraph('This is a new paragraph.')

# %%
doc.paragraphs[4].text
# Out:
# 'This is a new paragraph.'

# %%
doc.save('demo_test_modified.docx')

# %% [markdown]
# ## Loading CSV data into Python as Pandas Dataframe
#
# Download the datasets from Dataset and Inclass dataset

# %%
import os
os.getcwd()
# Out:
# 'F:\\All_Prep\\NLP Training\\Session\\1 Introduction to Text Mining and NLP'

# %%
# !pip install pandas
import pandas as pd

table = pd.read_csv('EmployeeDetails.csv')
table.head()
# Out:
#              Name   Age  Salary
# 0     Arjun singh    24   10000
# 1       Vibhor Jha   26   25000
# 2  Yoshita Debnath   23   15000
# 3   Abhitesh Setia   25   18000
# 4    Shaurya Nayar   26   30000

# %%
table
# Out:
#              Name   Age  Salary
# 0     Arjun singh    24   10000
# 1       Vibhor Jha   26   25000
# 2  Yoshita Debnath   23   15000
# 3   Abhitesh Setia   25   18000
# 4    Shaurya Nayar   26   30000
# 5      Disha Gupta   27   23000

# %% [markdown]
# ## Adding a new column into existing dataframe

# %%
import numpy as np
import pandas as pd
table2 = pd.read_csv('data.csv')
table2.head(1000)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
table2.shape
# Out:
# (569, 32)

# %%
df2 = table2[['id','diagnosis']]
length = len(table2)
df2['new_column'] = pd.Series(np.random.randn(length), index=df2.index)
df2.head()
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          id diagnosis  new_column
# 0    842302         M    0.448041
# 1    842517         M    0.699613
# 2  84300903         M   -1.014474
# 3  84348301         M   -0.059181
# 4  84358402         M    1.305861

# %%
df2.to_csv("data_modified_v0.1.csv")

# %% [markdown]
# ## Install NLTK
#
# Open cmd and write **pip install nltk
#
# After installation, type **python** in the command prompt. You should be able to use the python commands now
#
# Type **import nltk**, press enter
#
# Now type **nltk.download()**. Press enter and NLTK downloader should appear. Click on all tab and click download. This will download the nltk Collections at the specified locations. This will take time depending on your bandwidth and network speed.
#
# To save time, you can also download selective files.
#
# To exit from python in command prompt, type **quit()** and press enter

# %%
import nltk

# %%
nltk.download()

# %% [markdown]
# ## Reading NLTK corpora

# %%
nltk.data.find("corpora")
# Out:
# FileSystemPathPointer('C:\\Users\\ASUS\\AppData\\Roaming\\nltk_data\\corpora')

# %%
# import os
# import nltk
import nltk.corpus
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_tagged.zip', 'movie_reviews', 'mov
# ...

# %% [markdown]
# ## How to find the location of these datasets
#
# Remember the path from NLTK downloader page. If you can't find, then type nltk.download() to see the path again
#
# Path in my system: **C:\Users\ASUS\AppData\Roaming\nltk_data**

# %%
nltk.data.path.append("C:\\Users\\ASUS\\AppData\\Roaming\\nltk_data")
# Out:
# ['C:\\Users\\ASUS/nltk_data',
#  'C:\\nltk_data',
#  'D:\\nltk_data',
#  'E:\\nltk_data',
#  'C:\\Users\\ASUS\\Anaconda3\\nltk_data',
#  'C:\\Users\\ASUS\\Anaconda3\\share\\nltk_data',
#  'C:\\Users\\ASUS\\Anaconda3\\lib\\nltk_data',
#  'C:\\Users\\ASUS\\AppData\\Roaming\\nltk_data']

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# Let's read a file and see the content

# %%
hamlet = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
hamlet
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
for word in hamlet[:10]:
    print(word,sep=' ', end=' ')
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ]

# %% [markdown]
# Let's review another one - movie review

# %%
from nltk.corpus import movie_reviews
print(movie_reviews.categories())
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids('pos')
# Out:
# ['pos/cv000_29590.txt',
#  'pos/cv001_18431.txt',
#  'pos/cv002_15918.txt',
#  'pos/cv003_11664.txt',
#  'pos/cv004_11636.txt',
#  'pos/cv005_29443.txt',
#  'pos/cv006_15448.txt',
#  'pos/cv007_4968.txt',
#  'pos/cv008_29435.txt',
#  'pos/cv009_29592.txt',
#  'pos/cv010_29198.txt',
#  'pos/cv011_12166.txt',
#  'pos/cv012_29576.txt',
#  'pos/cv013_10159.txt',
#  'pos/cv014_13924.txt',
#  'pos/cv015_29439.txt',
#  'pos/cv016_4659.txt',
#  'pos/cv017_22464.txt',
#  'pos/cv018_20137.txt',
#  'pos/cv019_14482.txt',
#  'pos/cv020_8825.txt',
#  'pos/cv021_15838.txt',
#  'pos/cv022_12864.txt',
#  'pos/cv023_12672.txt',
#  'pos/cv024_6778.txt',
#  'pos/cv025_3108.txt',
#  'pos/cv026_29325.txt',
#  'pos/cv027_25219.txt',
#  'pos/cv028_26746.txt',
#  'pos/cv029_18643.txt',
#  'pos/cv030_21593.txt',
#  'pos/cv031_18452.txt',
#  'pos/cv032_22550.txt',
#  'pos/cv033_24444.txt',
#  'pos/cv034_29647.txt',
#  'pos/cv035_3954.txt',
#  'pos/cv036_16831.txt',
#  'pos/cv037_18510.txt',
# ...

# %%
file = nltk.corpus.movie_reviews.words('pos/cv001_18431.txt')
file
# Out:
# ['every', 'now', 'and', 'then', 'a', 'movie', 'comes', ...]

# %%
for word in file[:100]:
    print(word,sep=' ', end=' ')
# Out:
# every now and then a movie comes along from a suspect studio , with every indication that it will be a stinker , and to everybody ' s surprise ( perhaps even the studio ) the film becomes a critical darling . mtv films ' _election , a high school comedy starring matthew broderick and reese witherspoon , is a current example . did anybody know this film existed a week before it opened ? the plot is deceptively simple . george washington carver high school is having student elections . tracy flick ( reese witherspoon ) is an over

# %%
' '.join(file)
# Out:
# 'every now and then a movie comes along from a suspect studio , with every indication that it will be a stinker , and to everybody \' s surprise ( perhaps even the studio ) the film becomes a critical darling . mtv films \' _election , a high school comedy starring matthew broderick and reese witherspoon , is a current example . did anybody know this film existed a week before it opened ? the plot is deceptively simple . george washington carver high school is having student elections . tracy flick ( reese witherspoon ) is an over - achiever with her hand raised at nearly every question , way , way , high . mr . " m " ( matthew broderick ) , sick of the megalomaniac student , encourages paul , a popular - but - slow jock to run . and paul \' s nihilistic sister jumps in the race as well , for personal reasons . the dark side of such sleeper success is that , because expectations were so low going in , the fact that this was quality stuff made the reviews even more enthusiastic than t
# ...
