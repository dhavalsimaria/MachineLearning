# %%
import pandas as pd
import numpy as np
import csv

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
from sklearn.linear_model import LogisticRegression

# %%
#Load train data
df_train = pd.read_csv("D:\\APP\\NITW\\Graphical Models\\Assignment-9\\Problem-1\\train.csv",sep=",")

# %%
#Load test data
df_test = pd.read_csv("D:\\APP\\NITW\\Graphical Models\\Assignment-9\\Problem-1\\test.csv",sep=",")

# %%
df_train = df_train.drop(columns=['Unnamed: 0', 'id', 'Unnamed: 32'], axis=1)

# %%
df_test = df_test.drop(columns=['Unnamed: 0', 'id', 'Unnamed: 32'], axis=1)

# %%
df_train.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B       12.980         19.35           84.52      514.0
# 1         B       14.610         15.69           92.68      664.9
# 2         B        8.597         18.60           54.09      221.2
# 3         B       10.050         17.53           64.41      310.8
# 4         B       13.000         20.78           83.51      519.4
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.09579           0.11250         0.07107              0.02950
# 1          0.07618           0.03515         0.01447              0.01877
# 2          0.10740           0.05847         0.00000              0.00000
# 3          0.10070           0.07326         0.02511              0.01775
# 4          0.11350           0.07589         0.03136              0.02645
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 31 columns):
# diagnosis                  455 non-null object
# radius_mean                455 non-null float64
# texture_mean               455 non-null float64
# perimeter_mean             455 non-null float64
# area_mean                  455 non-null float64
# smoothness_mean            455 non-null float64
# compactness_mean           455 non-null float64
# concavity_mean             455 non-null float64
# concave points_mean        455 non-null float64
# symmetry_mean              455 non-null float64
# fractal_dimension_mean     455 non-null float64
# radius_se                  455 non-null float64
# texture_se                 455 non-null float64
# perimeter_se               455 non-null float64
# area_se                    455 non-null float64
# smoothness_se              455 non-null float64
# compactness_se             455 non-null float64
# ...

# %%
df_train.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   455.000000    455.000000      455.000000   455.000000
# mean     14.101422     19.365121       91.745516   651.793187
# std       3.474106      4.459912       23.904876   346.341835
# min       7.691000      9.710000       47.920000   170.400000
# 25%      11.695000     16.025000       75.100000   420.050000
# 50%      13.380000     18.770000       86.600000   551.700000
# 75%      15.705000     21.925000      103.300000   761.500000
# max      27.420000     39.280000      186.900000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       455.000000        455.000000      455.000000           455.000000
# mean          0.096134          0.102843        0.087691             0.048137
# std           0.013848          0.050111        0.078696             0.038281
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df_train_encoded = df_train.copy()
df_test_encoded = df_test.copy()

# %%
le = preprocessing.LabelEncoder()

# %%
df_train_encoded['diagnosis'] = le.fit_transform(df_train_encoded['diagnosis'])
df_test_encoded['diagnosis'] = le.fit_transform(df_test_encoded['diagnosis'])

# %%
X_train = df_train_encoded.drop(columns=['diagnosis'])
y_train = df_train_encoded['diagnosis']

# %%
X_test = df_test_encoded.drop(columns=['diagnosis'])
y_test = df_test_encoded['diagnosis']

# %%
mmScaler = MinMaxScaler()
mmScaler.fit(X_train)
X_train[X_train.columns] = mmScaler.transform(X_train[X_train.columns])
X_test[X_test.columns] = mmScaler.transform(X_test[X_test.columns])

# %% [markdown]
# **Naive Bayes Classifier**

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = gnb.predict(X_test)
nb_accuracy = np.round(metrics.accuracy_score(y_test, y_pred), 4)
print("Gaussian Naive Bayes model accuracy:", nb_accuracy)
# Out:
# Gaussian Naive Bayes model accuracy: 0.9211

# %% [markdown]
# **Logistic Regression Model**

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = lr.predict(X_test)
#lr.score(X_test, y_test)
lr_accuracy = np.round(metrics.accuracy_score(y_test, y_pred), 4)
print("Logistic Regression model accuracy:", lr_accuracy)
# Out:
# Logistic Regression model accuracy: 0.9474

# %%
#write your output in csv in this form(exactly to three decimals points)
data=[nb_accuracy, lr_accuracy]
result=pd.DataFrame(data)
result.to_csv('D:\\APP\\NITW\\Graphical Models\\Assignment-9\\Problem-1\\output.csv', header=False, index=False)
